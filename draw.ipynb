# %%
import nest_asyncio
from agent_graph import agent_graph
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
nest_asyncio.apply()  # Required for Jupyter Notebook to run async functions

display(
    Image(
        agent_graph.get_graph().draw_mermaid_png(
            curve_style=CurveStyle.LINEAR,
            node_colors=NodeStyles(first="#ffdfba", last="#baffc9", default="#fad7de"),
            wrap_label_n_words=9,
            output_file_path=None,
            draw_method=MermaidDrawMethod.PYPPETEER,
            background_color="white",
            padding=10,
        )
    )
)
# Out:
# [INFO] Starting Chromium download.
#   5%|▌         | 9.83M/183M [00:16<04:36, 625kb/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       4 from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
#       5 nest_asyncio.apply()  # Required for Jupyter Notebook to run async functions
#       7 display(
#       8     Image(
# ----> 9         agent_graph.get_graph().draw_mermaid_png(
#      10             curve_style=CurveStyle.LINEAR,
#      11             node_colors=NodeStyles(first="#ffdfba", last="#baffc9", default="#fad7de"),
#      12             wrap_label_n_words=9,
#      13             output_file_path=None,
#      14             draw_method=MermaidDrawMethod.PYPPETEER,
#      15             background_color="white",
#      16             padding=10,
#      17         )
#      18     )
#      19 )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/langchain_core/runnables/graph.py:679, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, frontmatter_config)
#     671 from langchain_core.runnables.graph_mermaid import draw_mermaid_png
#     673 mermaid_syntax = self.draw_mermaid(
#     674     curve_style=curve_style,
#     675     node_colors=node_colors,
#     676     wrap_label_n_words=wrap_label_n_words,
#     677     frontmatter_config=frontmatter_config,
#     678 )
# --> 679 return draw_mermaid_png(
#     680     mermaid_syntax=mermaid_syntax,
#     681     output_file_path=output_file_path,
#     682     draw_method=draw_method,
#     683     background_color=background_color,
#     684     padding=padding,
#     685 )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/langchain_core/runnables/graph_mermaid.py:279, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding)
#     276 if draw_method == MermaidDrawMethod.PYPPETEER:
#     277     import asyncio
# --> 279     img_bytes = asyncio.run(
#     280         _render_mermaid_using_pyppeteer(
#     281             mermaid_syntax, output_file_path, background_color, padding
#     282         )
#     283     )
#     284 elif draw_method == MermaidDrawMethod.API:
#     285     img_bytes = _render_mermaid_using_api(
#     286         mermaid_syntax, output_file_path, background_color
#     287     )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File ~/miniconda3/envs/main/lib/python3.12/asyncio/events.py:88, in Handle._run(self)
#      86 def _run(self):
#      87     try:
# ---> 88         self._context.run(self._callback, *self._args)
#      89     except (SystemExit, KeyboardInterrupt):
#      90         raise
#
# File ~/miniconda3/envs/main/lib/python3.12/asyncio/tasks.py:303, in Task.__step(self, exc)
#     301 _enter_task(self._loop, self)
#     302 try:
# --> 303     self.__step_run_and_handle_result(exc)
#     304 finally:
#     305     _leave_task(self._loop, self)
#
# File ~/miniconda3/envs/main/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/langchain_core/runnables/graph_mermaid.py:313, in _render_mermaid_using_pyppeteer(mermaid_syntax, output_file_path, background_color, padding, device_scale_factor)
#     310     msg = "Install Pyppeteer to use the Pyppeteer method: `pip install pyppeteer`."
#     311     raise ImportError(msg) from e
# --> 313 browser = await launch()
#     314 page = await browser.newPage()
#     316 # Setup Mermaid JS
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/pyppeteer/launcher.py:307, in launch(options, **kwargs)
#     239 async def launch(options: dict = None, **kwargs: Any) -> Browser:
#     240     """Start chrome process and return :class:`~pyppeteer.browser.Browser`.
#     241     This function is a shortcut to :meth:`Launcher(options, **kwargs).launch`.
#     242     Available options are:
#    (...)
#     305         option with extreme caution.
#     306     """
# --> 307     return await Launcher(options, **kwargs).launch()
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/pyppeteer/launcher.py:120, in Launcher.__init__(self, options, **kwargs)
#     118 if not self.chromeExecutable:
#     119     if not check_chromium():
# --> 120         download_chromium()
#     121     self.chromeExecutable = str(chromium_executable())
#     123 self.cmd = [self.chromeExecutable] + self.chromeArguments
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/pyppeteer/chromium_downloader.py:138, in download_chromium()
#     136 def download_chromium() -> None:
#     137     """Download and extract chromium."""
# --> 138     extract_zip(download_zip(get_url()), DOWNLOADS_FOLDER / REVISION)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/pyppeteer/chromium_downloader.py:95, in download_zip(url)
#      93     total_length = 0
#      94 process_bar = tqdm(total=total_length, unit_scale=True, unit='b')
# ---> 95 for chunk in r.stream(10240):
#      96     _data.write(chunk)
#      97     process_bar.update(len(chunk))
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/envs/main/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/miniconda3/envs/main/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/miniconda3/envs/main/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/main/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
#   5%|▌         | 9.84M/183M [00:27<04:36, 625kb/s]
